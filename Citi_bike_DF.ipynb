# %%
dec19 = pd.read_csv('Resources/201912-citibike-tripdata.csv')

# %%
jan20 = pd.read_csv('Resources/202001-citibike-tripdata.csv')

# %%
june20 = pd.read_csv('Resources/202006-citibike-tripdata.csv')

# %%
dec19
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1               1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4               1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...              ...                       ...                       ...
# 955205            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 955206           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 955207           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id                start station name  \
# ...

# %%
data_df=pd.concat([dec19, jan20])

# %%
data_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1                1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                 723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                 404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4                1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...               ...                       ...                       ...
# 1240591          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 1240592           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 1240593           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 1240594           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 1240595           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#          start station id          start station name  start station latitude  \
# ...

# %%
newdata_df=pd.concat([data_df, june20])

# %%
newdata_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1                1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                 723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                 404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4                1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...               ...                       ...                       ...
# 1882268           685  2020-06-30 23:59:41.1160  2020-07-01 00:11:06.7790
# 1882269           446  2020-06-30 23:59:46.4260  2020-07-01 00:07:13.0860
# 1882270           439  2020-06-30 23:59:47.4770  2020-07-01 00:07:06.5590
# 1882271           890  2020-06-30 23:59:53.3950  2020-07-01 00:14:43.4270
# 1882272           433  2020-06-30 23:59:53.9010  2020-07-01 00:07:07.0950
#
#          start station id         start station name  start station latitude  \
# ...

# %%
newdata_df.to_csv("citibike.csv")
